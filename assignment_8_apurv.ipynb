# %% [markdown]
# <a href="https://colab.research.google.com/github/apurvv28/ML-Labs/blob/assignment-8/assignment_8_apurv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Assignment 8
#
#
# Apply appropriate ML algorithm on a dataset collected in a cosmetic shop showing details of customers to predict customer response for special offer. Create confusion matrix based on above data and find.
#
#
# a. Accuracy
#
#
# b. Precision
#
#
# c. Recall
#
#
# d. F1 Score
#
#
# By Apurv Saktepar, Roll No. 11, SEDA Division, PRN - 1252090011

# %% [markdown]
# 1. Importing Required Libraries
